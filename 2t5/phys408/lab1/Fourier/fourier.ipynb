# %%
dist = 330 #cm
zero_width = 24.49#mm
pixel_per_mm = 20.53 #or is it???

# %%
widths_mm = [0.21397841098296613, 0.8559136439318645, 1.711827287863729, 3.423654575727458]
widths_mm = [zero_width - x for x in widths_mm]
widths_mm
# Out:
# [24.27602158901703, 23.634086356068135, 22.778172712136268, 21.06634542427254]

# %%
import numpy as np
x = [0.25, 1,2,4]
l = 632.8*10**(-6)
z = (263.8+120.4)*10
w= []
for a in x:
  w.append(a*np.sqrt(l*z/np.pi))
print(w)
zero = 24.53
w = [zero - a for a in w]
w
# Out:
# [0.21992620886675102, 0.8797048354670041, 1.7594096709340081, 3.5188193418680163]
# [24.31007379113325, 23.650295164533, 22.770590329065993, 21.011180658131984]

# %% [markdown]
# CL distances: 2cm (closer to source), -2cm, -4cm
#
#
# Beam Radius: 3.5cm ish
#
#
# Nozon object plane: 20.8 (from CL lens)
# FT lens 74 ish cm from CK lens

# %% [markdown]
# Everything relative to the polarizer:
#
# spatial filter: 5.4cm
# beam-narrower: 27.8cm
# CL: 71.6cm
# Obj plane (mesh): 92.5cm
# FTL: 146.2cm
# Fourier plane: 196.5cm
# FPL: 221.8cm

# %% [markdown]
# Everything relative to the polarizer:
#
# spatial filter: 7.25cm
# CL: 61.6cm
# Mesh: 77cm
# FTL: 130.9cm
# FPL: 208.7cm
# Fourier transform plane: 181.5cm

# %% [markdown]
# FINAL FINAL MEASUREMENTS:
#
# lens positions (not knob podiitons)
#
# From the laser:
#
# polariser 1: 7cm
# polariser 2: 15.8
# spatial filter (reference to pinhole): 37.8cm
# cullimating lens: 76cm
# object plane: 92.5
# Fourier transform lens: 159.5cm
# Fourier transform plane: 197cm
# FPIL: 202.5
