# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [9, 3]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
plt.rcParams.update({'font.size': 11})

# %%
m1=1
m2=4
mu=m1*m2/(m1+m2)
l={1:2, 2:1, 3:6}
n=[1, 2, 3]
Gn={1:1, 2:1, 3:3}
alpha={i:m1*m2*Gn[i] for i in n}

# %%
figure, axis = plt.subplots(1, 4)
# figure.set_figwidth(15)
# figure.set_figheight(7)
r=np.linspace(0.5, 4, 1000)
U=[l[i]**2/2/mu/r**2-alpha[i]/r**i for i in n]
axis[0].plot(r, U[0])
axis[1].plot(r, U[1])
axis[2].plot(r, -U[1])
axis[3].plot(r, U[2])

figure.tight_layout(rect=[0, 0.03, 1, 0.90])
figure.suptitle('U(r) for Different Values of n')
axis[0].set_title('n=1')
axis[1].set_title('n=2, C<0')
axis[2].set_title('n=2, C>0')
axis[3].set_title('n=3')
plt.setp(axis[:], xlabel='r');
plt.setp(axis[0], ylabel='U(r)');

# %%
l=2
mu=1
alpha2=1
E=2
C=l**2/2/mu-alpha2
e=np.sqrt(np.abs(1-2*mu*alpha2/l**2))
p2=np.sqrt(C/E)

phi = np.linspace(-1/2/e*np.pi+1e-2, 1/2/e*np.pi-1e-2, 10000)
r=p2/np.cos(e*phi)
print(e, p2, C)
# Out:
# 0.7071067811865476 0.7071067811865476 1.0

# %%
print()

# %%
plt.scatter(r*np.cos(phi), r*np.sin(phi), c=np.arange(len(phi)))
plt.xlim(-4, 4)
plt.ylim(-4, 4)
# Out:
# (-4.0, 4.0)
